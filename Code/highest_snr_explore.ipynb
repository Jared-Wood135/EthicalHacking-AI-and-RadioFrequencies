# %% [markdown]
# <div style="
#     padding: 15px 20px;
#     margin: 10px 0;
#     border-left: 8px solid #4F7942;
#     background-color: rgba(255, 191, 0, 0.05);
#     border-radius: 4px;
# ">
#
# ## Table of Contents:
#
# - [Imports](#imports)
# - [Signal Visualizations](#signal-visualizations)
#
# </div>

# %% [markdown]
# ##### **IMPORTANT**:
# - Given that the nature of the `highest_snr_reduced_df.hdf5` is uniformly distributed and appears to visualize I/Q signals properly, data cleaning/preparation will **NOT** be conducted.  Thus, this data exploration is an immediate follow-on from `acquire.ipynb`.
#
# ---
#
# ##### **ORIENTATION**:
# - Since the `highest_snr_reduced_df.hdf5` only has I/Q signal data, signal modulation type, and all signals are at 30 SNR, we will simply visualize each signal modulation type to observe any unique trends.  This is to say that there will be 24 total signal visualizations.
#
# ---
#
# ##### **SUMMARY**:
# - Signal Visualizations
#     - The SNR being the highest possible value makes observing the I/Q wavelengths very obvious where some modulation types, like AM and FM, appear to be visually distinct from all the other modulation types that may not be immediately apparent to the human eye.
#     - Given the clear distinction of each signal modulation types, when sending this data into a Random Forest Classifier Machine Learning process, it is likely that the baseline model will perform very well.  This is yet to be seen until proceeding through `highest_snr_baseline.ipynb`.

# %% [markdown]
# <div style="
#     padding: 15px 20px;
#     margin: 10px 0;
#     border-left: 8px solid #4F7942;
#     background-color: rgba(255, 191, 0, 0.05);
#     border-radius: 4px;
# ">
#
# ## Imports
#
# - [Back to Table of Contents](#table-of-contents)
#
# </div>

# %%
# Pull down functions specific for this notebook
import highest_snr_explore as e

# %% [markdown]
# <div style="
#     padding: 15px 20px;
#     margin: 10px 0;
#     border-left: 8px solid #4F7942;
#     background-color: rgba(255, 191, 0, 0.05);
#     border-radius: 4px;
# ">
#
# ## Signal Visualizations
#
# - [Back to Table of Contents](#table-of-contents)
#
# </div>

# %%
# Visualize one signal of every modulation type (24)
e.vis_all_mod_types()
# Out:
# Signal index: 103
# Signal shape: (1024, 2)
# Modulation Class: OOK
# SNR: 30
# ...
# Signal index: 1103
# Signal shape: (1024, 2)
# Modulation Class: 4ASK
# SNR: 30
# ...
# Signal index: 2103
# Signal shape: (1024, 2)
# Modulation Class: 8ASK
# SNR: 30
# ...
# Signal index: 3103
# Signal shape: (1024, 2)
# Modulation Class: BPSK
# SNR: 30
# ...
# Signal index: 4103
# Signal shape: (1024, 2)
# Modulation Class: QPSK
# SNR: 30
# ...
# Signal index: 5103
# Signal shape: (1024, 2)
# Modulation Class: 8PSK
# SNR: 30
# ...
# Signal index: 6103
# Signal shape: (1024, 2)
# Modulation Class: 16PSK
# SNR: 30
# ...
# Signal index: 7103
# Signal shape: (1024, 2)
# Modulation Class: 32PSK
# SNR: 30
# ...
# Signal index: 8103
# Signal shape: (1024, 2)
# Modulation Class: 16APSK
# SNR: 30
# ...
# Signal index: 9103
# Signal shape: (1024, 2)
# Modulation Class: 32APSK
# SNR: 30
# ...
# Signal index: 10103
# Signal shape: (1024, 2)
# Modulation Class: 64APSK
# SNR: 30
# ...
# Signal index: 11103
# Signal shape: (1024, 2)
# Modulation Class: 128APSK
# SNR: 30
# ...
