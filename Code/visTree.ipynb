# %% [markdown]
# <div style="
#     padding: 15px 20px;
#     margin: 10px 0;
#     border-left: 8px solid #4F7942;
#     background-color: rgba(255, 191, 0, 0.05);
#     border-radius: 4px;
# ">
#
# ## Table of Contents:
#
# - [Imports](#imports)
# - [Original Dataset Baseline Model](#original-dataset-baseline-model)
# - [Feature Engineered 105 Baseline Model](#feature-engineered-105-baseline-model)
# - [Feature Engineered Top 25 Model](#feature-engineered-top-25-model)
#
# </div>

# %% [markdown]
# <div style="
#     padding: 15px 20px;
#     margin: 10px 0;
#     border-left: 8px solid #4F7942;
#     background-color: rgba(255, 191, 0, 0.05);
#     border-radius: 4px;
# ">
#
# ## Imports
#
# - [Back to Table of Contents](#table-of-contents)
#
# </div>

# %%
import visTree as v

# %% [markdown]
# <div style="
#     padding: 15px 20px;
#     margin: 10px 0;
#     border-left: 8px solid #4F7942;
#     background-color: rgba(255, 191, 0, 0.05);
#     border-radius: 4px;
# ">
#
# ## Original Dataset Baseline Model
#
# - [Back to Table of Contents](#table-of-contents)
#
# </div>

# %%
MODEL_PATH = "../Models/highest_snr_random_forest_baseline.joblib"
SAVE_PATH = "../Reports/original_baseline_tree.png"

v.plot_simplified_random_forest_tree(model_filepath=MODEL_PATH, output_filepath=SAVE_PATH)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator RandomForestClassifier from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Simplified tree saved to: ../Reports/original_baseline_tree.png

# %% [markdown]
# <div style="
#     padding: 15px 20px;
#     margin: 10px 0;
#     border-left: 8px solid #4F7942;
#     background-color: rgba(255, 191, 0, 0.05);
#     border-radius: 4px;
# ">
#
# ## Feature Engineered 105 Baseline Model
#
# - [Back to Table of Contents](#table-of-contents)
#
# </div>

# %%
MODEL_PATH = '../Models/highest_snr_feature_engineered_random_forest.joblib'
SAVE_PATH = "../Reports/feature_engineered_105_baseline_tree.png"

v.plot_simplified_random_forest_tree(model_filepath=MODEL_PATH, output_filepath=SAVE_PATH)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator RandomForestClassifier from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Simplified tree saved to: ../Reports/feature_engineered_105_baseline_tree.png

# %% [markdown]
# <div style="
#     padding: 15px 20px;
#     margin: 10px 0;
#     border-left: 8px solid #4F7942;
#     background-color: rgba(255, 191, 0, 0.05);
#     border-radius: 4px;
# ">
#
# ## Feature Engineered Top 25 Model
#
# - [Back to Table of Contents](#table-of-contents)
#
# </div>

# %%
MODEL_PATH = "../Models/highest_snr_feature_engineered_random_forest_gridsearch.joblib"
SAVE_PATH = "../Reports/feature_engineered_top_25_tree.png"

v.plot_simplified_random_forest_tree(model_filepath=MODEL_PATH, output_filepath=SAVE_PATH)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator RandomForestClassifier from version 1.8.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Simplified tree saved to: ../Reports/feature_engineered_top_25_tree.png
